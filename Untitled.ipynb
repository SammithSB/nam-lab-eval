# %%
# Install required packages.
import os
import torch
import os.path as osp

# %%
torch
# Out:
# <module 'torch' from '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/__init__.py'>

# %%
# !pip install torch-scatter
# Out:
# ...
#   Using cached torch_scatter-2.0.9.tar.gz (21 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/sammithsbharadwaj/opt/miniconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/r4/hwr2k7h54y10cljgzdmgbgd00000gn/T/pip-install-lv2x6khk/torch-scatter_76f66fd70f914076ab7c45eca2dfad88/setup.py'"'"'; __file__='"'"'/private/var/folders/r4/hwr2k7h54y10cljgzdmgbgd00000gn/T/pip-install-lv2x6khk/torch-scatter_76f66fd70f914076ab7c45eca2dfad88/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/r4/hwr2k7h54y10cljgzdmgbgd00000gn/T/pip-pip-egg-info-hpxp0vgl
# ...
